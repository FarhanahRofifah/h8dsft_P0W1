# %% [markdown]
# # Perkenalan
#
# Nama : Farhanah Rofifah

# %% [markdown]
# Batch : 003

# %% [markdown]
# Objective yang ingin dicapai : Mengetahui nama-nama pokemon yang masuk kepada jenis poison dengan speed lebih dari sama dengan 80

# %%
#import library
import pandas as pd
import numpy as np

# %%
#Data loading
df = pd.read_csv(r'C:\Users\ASUS\OneDrive\Desktop\HACKTIV8\G Challange\Pokemon.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
#missing values
df['Type 2']
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
df['Type 2'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 2, Length: 800, dtype: bool

# %%
missing_values = ['n/a','na','--']

# %%
df['Type 2']
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
cnt=0
for row in df['Type 2']:
    try:
        int(row)
        df.loc[cnt, 'Type 2']=np.nan
    except ValueError:
        pass
    cnt+=1

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df['Type 2'].fillna('ICE', inplace=True)

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     ICE    309  39      52       43
# 5  5                 Charmeleon   Fire     ICE    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     ICE    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
#Mengganti nama kolom
df.rename(columns={u'#':'ID'}, inplace=True)

# %%
df.head()
# Out:
#    ID                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1              Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                Ivysaur  Grass  Poison    405  60      62       63
# 2   3               Venusaur  Grass  Poison    525  80      82       83
# 3   3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4             Charmander   Fire     ICE    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Menghapus kolom yang tidak digunakan
del df['ID']

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     ICE    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Data Query
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     ICE    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[
    (df['Total'] == 318) &
    (df['HP'] < 50) &
    (df['Attack'] < 50) &
    (df['Type 2'] == 'Poison')
]
# Out:
#         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
df[
    (df['Total'] >= 600) &
    (df['HP'] == 50) &
    (df['Attack'] >= 100) &
    (df['Type 2'] == 'Fairy')
]
# Out:
#                     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 795              Diancie   Rock  Fairy    600  50     100      150      100
# 796  DiancieMega Diancie   Rock  Fairy    700  50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True

# %%
df[
    (df['Total'] > 500) &
    (df['HP'] == 80) &
    (df['Attack'] >= 100) &
    (df['Type 1'] == 'Fire')
]
# Out:
#                       Name Type 1    Type 2  Total  HP  Attack  Defense  \
# 278               Blaziken   Fire  Fighting    530  80     120       70
# 279  BlazikenMega Blaziken   Fire  Fighting    630  80     160       80
# 799              Volcanion   Fire     Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 278      110       70     80           3      False
# 279      130       80    100           3      False
# 799      130       90     70           6       True

# %%
#Grouping and Aggregating
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     ICE    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.groupby('Type 1',sort = False)['HP'].sum()
# Out:
# Type 1
# Grass       4709
# Fire        3635
# Water       8071
# Bug         3925
# Normal      7573
# Poison      1883
# Electric    2631
# Ground      2361
# Fairy       1260
# Fighting    1886
# Psychic     4026
# Rock        2876
# Ghost       2062
# Ice         1728
# Dragon      2666
# Dark        2071
# Steel       1761
# Flying       283
# Name: HP, dtype: int64

# %%
df[
    (df['Type 2']=='Poison')&
    (df['Speed']>= 80)
].groupby(['Name','Speed','Total','Defense'])['Generation'].count()
# Out:
# Name                   Speed  Total  Defense
# BeedrillMega Beedrill  145    495    40         1
# Gastly                 80     310    30         1
# Gengar                 110    500    60         1
# GengarMega Gengar      130    600    80         1
# Haunter                95     405    45         1
# Qwilfish               85     430    75         1
# Roserade               90     515    65         1
# Scolipede              112    485    89         1
# Tentacruel             100    515    65         1
# Venomoth               90     450    60         1
# Venusaur               80     525    83         1
# VenusaurMega Venusaur  80     625    123        1
# Name: Generation, dtype: int64

# %%
#Pandas Visualization
# %matplotlib inline

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Total'].plot(label='Total',legend=True)
df['HP'].plot(label='HP',legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Setelah melakukan riset data dengan menggunakan library pandas dan numpy, diketahui nama-nama pokemon jenis poison di Type 2 dengan nilai speed lebih dari sama dengan 80 yaitu terdapat 12 nama pokemon. Dua belas nama pokemon yang termasuk adalah BeedrillMega Beedrill, Gastly, Gengar, GengarMega Gengar, Haunter, Qwilfish, Roserade, Scolipede, Tentacruel, Venomoth, Venusaur, dan VenusaurMega Venusaur.
